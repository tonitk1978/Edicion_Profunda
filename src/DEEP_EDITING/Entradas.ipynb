# %% [markdown]
# # Deep Editing

# %% [markdown]
# ## Importando Librerias

# %%
import numpy as np
import os as OperativeSystem
import matplotlib.pyplot as plt
import datetime
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from numpy import genfromtxt
import shutil
from heapq import nsmallest
from sklearn.neighbors import NearestNeighbors
from collections import Counter
import sklearn
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import TomekLinks
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.under_sampling import CondensedNearestNeighbour
from imblearn.under_sampling import OneSidedSelection
from imblearn.over_sampling import ADASYN
from imblearn.over_sampling import BorderlineSMOTE
from keras.models import load_model 
import h5py
import tensorflow as tf
from tensorflow import keras
from sklearn.utils import shuffle

# %% [markdown]
# ## Definiendo Parametros

# %%
directorio="../../"
#directorioPrueba=directorio+"Datasets/txt/test/"
directorioEntrenamientoOut=directorio+"Datasets/txt/sampled_train2/"
directorioEntrenamientoIn=directorio+"Datasets/txt/sampled_train/"
directorioModelosIn=directorio+"modelos/"
directorioPesosIn=directorio+"pesos/"
directorioModelosOut=directorio+"modelos2/"
directorioPesosOut=directorio+"pesos2/"
bases=["Salinas"]
epocas=[500]
lotes=[500]
clases=[17]
bandas=[224]
OS=["","_SMOTE","_ROS"]
E = ["_ENN", "_TL", "_OSS"]
metodosDeEdicionProfunda = {
    "_TL": TomekLinks(sampling_strategy='all', n_jobs=7),
    "_ENN": EditedNearestNeighbours(sampling_strategy='all', n_jobs=7),
    "_OSS": OneSidedSelection(sampling_strategy='all', n_jobs=7)
}

n_capas=["C0"]

# %% [markdown]
# ##

# %%
inicio= datetime.datetime.now()
contadorBases=0
for base in bases:
    print("\n\n\n")
    print(">>>>> Base: ",base)
    for capa in n_capas:
        print(">>>>>>>>>> Capa: ",capa)
        print("\n\n\n")
        try:

            for os in OS:
                for e in E:

                    print("\n\n")
                    print(">>>(SIN_EDICION) Metodo de submuestreo: ",e," con el metodo de re muestreo:  ",os," para la capa: ",capa, " con la base:  ",base )
                   
                    
                    print("\n")
                    inicio=datetime.datetime.now()        

                    
                    #Leer los valores del archivo de entrenamiento 
                    carga=np.loadtxt(str(directorioEntrenamientoIn+str(base)+os+".txt"))
                    #carga=shuffle(carga)
                    datos=carga[:,0:carga.shape[1]-1]
                    clases=carga[:,carga.shape[1]-1]


                    ###############################################################################################
                    # No Edicion
                    print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>> ",metodosDeEdicionProfunda[e])
                    sampler = metodosDeEdicionProfunda[e]
                    X_sampled, y_sampled = sampler.fit_resample(datos, clases)

                    fmt = ['%0.15f']* X_sampled.shape[1] + ['%d']  # Formato flotante para características, entero para etiquetas
                    np.savetxt(str(directorioEntrenamientoOut+str(base)+str(capa)+""+e+""+os+".txt"), np.column_stack((X_sampled, y_sampled)), fmt=fmt)
                    #
                    ####################################################################################################

                    fin=datetime.datetime.now()  
                    print(">>> Tiempo de edicion: ",(fin-inicio))
                    

        except Exception as error:
            print("> Error realizando el proceso para la base: ",base," con el metodo de muestreo: ",capa)
            print(">>Error: ",error)
    contadorBases=contadorBases+1
fin= datetime.datetime.now()
print("\n\n\n")
print(">>> Proceso terminado en : ",(fin-inicio))
# Out:
# >>>>> Base:  Salinas
# >>>>>>>>>> Capa:  C0
#
#
#
#
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _ENN  con el metodo de re muestreo:     para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  EditedNearestNeighbours(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:00:44.262612
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _TL  con el metodo de re muestreo:     para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  TomekLinks(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:00:43.279166
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _OSS  con el metodo de re muestreo:     para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  OneSidedSelection(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:00:10.127130
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _ENN  con el metodo de re muestreo:   _SMOTE  para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  EditedNearestNeighbours(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:36:15.624852
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _TL  con el metodo de re muestreo:   _SMOTE  para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  TomekLinks(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:36:21.196883
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _OSS  con el metodo de re muestreo:   _SMOTE  para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  OneSidedSelection(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:32:42.354085
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _ENN  con el metodo de re muestreo:   _ROS  para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  EditedNearestNeighbours(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:36:36.697546
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _TL  con el metodo de re muestreo:   _ROS  para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  TomekLinks(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:36:35.126742
#
#
#
# >>>(SIN_EDICION) Metodo de submuestreo:  _OSS  con el metodo de re muestreo:   _ROS  para la capa:  C0  con la base:   Salinas
#
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> >>>>>>>>>  >>>>>>  OneSidedSelection(n_jobs=7, sampling_strategy='all')
# >>> Tiempo de edicion:  0:32:36.519438
#
#
#
#
# >>> Proceso terminado en :  0:32:36.520437
